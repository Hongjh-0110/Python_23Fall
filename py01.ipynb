# %% [markdown]
# # python 是最好的语言

# %%
# eelkdjgie;lknsd jdlk;gjeisnv

# %%
print ("hello world")
# Out:
# hello world

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
n='好学';f'hello world,{n}'
# Out:
# 'hello world,好学'

# %%
for n in ['好学','逃学','留学']:print (f'hello world,{n}')
# Out:
# hello world,好学
# hello world,逃学
# hello world,留学

# %%
print (n)
# Out:
# 留学

# %%
n='The first class of python'
print(n[2:-3])
#[a:b] 3到倒数第4
# Out:
# e first class of pyt

# %%
import pandas as pd
df=pd.read_excel('data/studentselectedcoursebook2.xls',header=1)
df.head(5)
# Out:
#           学   号 姓  名 性  别             院系             专业     年级          班级  \
# 0  320180941310  李婷婷    女    信息科学与工程学院       计算机科学与技术    2018级   2018计算机2班
# 1  320180941400  刘萌月    女    信息科学与工程学院       计算机科学与技术    2018级   2018计算机2班
# 2  320180938600   李艺    女    信息科学与工程学院      电子信息科学与技术    2019级   2019级电信2班
# 3  320180942001  杨金涛    男    信息科学与工程学院       计算机科学与技术    2019级  2019级计算机1班
# 4  320190940931  蔡子晰    男    信息科学与工程学院       计算机科学与技术    2019级  2019级计算机1班
#
#   选课属性 考核方式  考试性质 是否缓考  成绩
# 0   任选  未确定  正常考试  非缓考 NaN
# 1   任选  未确定  正常考试  非缓考 NaN
# 2   限选  未确定    重修  非缓考 NaN
# 3   限选  未确定  正常考试  非缓考 NaN
# 4   限选  未确定  正常考试  非缓考 NaN

# %%
df.columns
# Out:
# Index(['学   号', '姓  名', '性  别', '院系', '专业', '年级', '班级', '选课属性', '考核方式', '考试性质',
#        '是否缓考', '成绩'],
#       dtype='object')

# %%
for n in df['姓  名'][:6] : print(f'hello world,{n[:2]}')
for n in df['姓  名'][:6] : print(f'hello world,{n[1:]}',end =' ')
#end=':' 不换行
# Out:
# hello world,李婷
# hello world,刘萌
# hello world,李艺
# hello world,杨金
# hello world,蔡子
# hello world,范琼
# hello world,婷婷 hello world,萌月 hello world,艺 hello world,金涛 hello world,子晰 hello world,琼耀

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']  #解决中文显示乱码问题
plt.rcParams['axes.unicode_minus']=False  #解决坐标轴负数的负号显示问题

# %%
# %pylab inline 
#我要画图了，在这个浏览器上
df['性  别'].value_counts().plot(kind='bar') 
#取出性别数组，统计值，画bra类型的图
#问题 搜jupyternotebook画图乱码    见上一框
#问题 搜可以把提醒但没错的信息关掉
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <Axes: >

# %%
df['性  别']
# Out:
# 0     女
# 1     女
# 2     女
# 3     男
# 4     男
# 5     男
# 6     女
# 7     男
# 8     男
# 9     男
# 10    男
# 11    男
# 12    男
# 13    男
# 14    男
# 15    男
# 16    男
# 17    男
# 18    男
# 19    男
# 20    男
# 21    男
# 22    男
# 23    男
# 24    男
# 25    女
# 26    男
# 27    男
# 28    男
# 29    男
# 30    男
# 31    女
# 32    女
# 33    女
# 34    男
# 35    女
# 36    女
# 37    男
# 38    女
# 39    男
# Name: 性  别, dtype: object

# %%
df['性  别'].value_counts()
# Out:
# 男    29
# 女    11
# Name: 性  别, dtype: int64

# %%
from flask import Flask
app=Flask(__name__)
@app.route("/")
def home():return 'hello world'
app.run()
#
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Sep/2023 21:25:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Sep/2023 21:25:16] "GET /favicon.ico HTTP/1.1" 404 -

# %%
import pandas as pd
df = pd.read_excel('Flask_hello/hello/py_big.xls', header=1)
df.head(2)
# Out:
#           学   号 姓  名 性  别             院系            专业     年级          班级  \
# 0  320190941621  马海洲    男    信息科学与工程学院      计算机科学与技术    2019级  2019级计算机1班
# 1  320190942421  姚佳男    男    信息科学与工程学院      计算机科学与技术    2019级  2019级计算机1班
#
#   选课属性 考核方式  考试性质 是否缓考  成绩
# 0   限选  未确定  正常考试  非缓考 NaN
# 1   限选  未确定  正常考试  非缓考 NaN

# %%
df.columns
# Out:
# Index(['学   号', '姓  名', '性  别', '院系', '专业', '年级', '班级', '选课属性', '考核方式', '考试性质',
#        '是否缓考', '成绩'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 解决中文显示乱码问题
plt.rcParams['axes.unicode_minus'] = False  # 解决坐标轴负数的负号显示问题

# %pylab inline
# 我要画图了，在这个浏览器上
df['班级'].value_counts().plot(kind='bar')
# 取出性别数组，统计值，画bra类型的图
# 问题 搜jupyternotebook画图乱码    见上一框
# 问题 搜可以把提醒但没错的信息关掉
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <Axes: >

# %%
'''from flask import Flask
app=Flask(__name__)
@app.route("/")
def home():return 'hello world'
app.run()'''
# Out:
# 'from flask import Flask\napp=Flask(__name__)\n@app.route("/")\ndef home():return \'hello world\'\napp.run()'

# %%
x = 55
y = 0
z = 233
s = 9
j = 4
d = 3

long_string = "This is a very long string with many words in it"
d
# Out:
# 3

# %%
# pandas数据分析最强包

# %%
# nbextensions

# %%
print("hello world")
# Out:
# hello world

# %%
a = 1
b = 2
y = a+b
print(a)
# Out:
# 1

# %% [raw]
# *这里显示的是斜体y=a+b*
#
# ![858714535_cover.jpg](attachment:858714535_cover.jpg)

# %%
n = 1
if n == 1:
    print('ok')
    print('====')
else:
    print('not ok')
print('over')
# tab键缩进，有时候会被翻成空格
# Out:
# ok
# ====
# over

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
n = 1
n
n = 9.8
n*3
n = 'lzu'
n*3
# Out:
# 'lzulzulzu'

# %%
n = [1, 2, 3]
len(n)
n.__len__()
max(n), min(n)
n = [1, 2+3, 3 > 5]
n
p = ['a', 'b', 'c']
p
# Out:
# ['a', 'b', 'c']

# %%
a = 1
l = ['a', 'b', 'c']
print(a)
print(l)
# Out:
# 1
# ['a', 'b', 'c']

# %%
n=[1,2,3];n.__len__();max(n),min(n)
n=[1,2+3,3<1];n
n=[1,2+3,3<1,lambda x:(x**2,x*3)];n[3](2)[1]
# Out:
# 6

# %%
max([1,3,7])
n=[1,max([1,3,7])]
n[1]
# Out:
# 7

# %%
a=1
b=2
a,b
# Out:
# (1, 2)

# %%
a,b=1,2
a,b=b,a
a,b
# Out:
# (2, 1)

# %%
x,y,z=1,2,3
x,y,z=z,x,y
x,y,z
# Out:
# (3, 1, 2)

# %%
# %%javascript
# require("base/js/utils").load_extensions("highlighter/highlighter")
